# %% [markdown]
# <h3><b>Introduction to Data Analytics - Exercise set 4, exercise 2</b></h3>
# <h4><b>Honey production dataset</b></h4>
# <img src="http://srv.plab.fi/~tuomasv/data_analytics_2023_images/exercise_set_4/honey.png" />

# %% [markdown]
# <hr /><h1>!!!!! IMPORTANT !!!!!</h1>
#
# <h2>Do not use generative AI in this exercise!</h2>
# <b>Remember:</b> in working life, we are not allowed to freely share our data with just any generative AI, since the data is often sensitive and owned by a client.
#
# Generative AIs would use the data to train themselves in the future, which is a violation of regulations.
# The point of this exercise set is to <b>MANUALLY</b> inspect the plots in the examples and learn how to see trends and features in the data.
#
# See also the materials discussing the usage of AI in this course!
# <hr />

# %% [markdown]
# <b>Tip:</b> You can just click "Run All" to see the results of this notebook. Some of these exercises have some heavy plots that can take even 1 minute to produce.

# %% [markdown]
# <b>Remember:</b> not every dataset has interesting correlations and/or features (too much randomness or variance usually, or not enough data). Also, not each correlation implies there's a causation. Finally, not every plot is useful, that's why it's important to try multiple plots in order to "see under the hood". Typically pair plots, joint plots, regression plots, heatmaps and box plots are most useful, but there are some exceptions too.

# %% [markdown]
# <h3><b>Quick summary of data:</b></h3>
#
# <p>This dataset contains a sample of honey production in USA from various different states, from years 1995 to 2021. There are many interesting variables in the dataset, including production (colonies number * yield per colony), value of production (production * average price), amount of stocks owned by the producer, average price, colony number and yield per colony.</p>
# <p>This notebook uses heavily the quantile -feature in the query-function in pandas. This allows us to inspect to the top 25% honey companies in the set based on production, as well se companies in the 25-50%, 50-75% quantiles as well as lowest 25% companies.See code comments for more details what has been done with the dataset.</p>
# <p>Kaggle page: <a href="https://www.kaggle.com/datasets/mohitpoudel/us-honey-production-19952021">https://www.kaggle.com/datasets/mohitpoudel/us-honey-production-19952021</a></p>

# %% [markdown]
# <h3><b>Questions for this exercise:</b></h3>
# <b>Answer the questions either as code comments or as markdown. Use separate cells to write your answers.</b><br/><br/>
# <li>Can you find any states that have got more successful in terms of different variables in this dataset?</li>
# <li>Something has happened to honey production overall during the years. Which variables show this best? Can you find anything with Google why this phenomenon might have a happened?</li>
# <li>Which seaborn plots are useful in this notebook, and which are not? Why? (you can remove the unnecessary plots from this notebook if you wish too). Note: there are many not-so-useful plots in this notebook.</li>
# <li>Which are more useful in this case, correlations or plots? Or are they both useful?</li>
# <li>How does the hue change the perspective of the data in the regression plots?</li>
#
# <b>Extra questions/tasks for extra points:</b>
# <li>If you find new insight or features in this dataset by using some other plots and/or pandas tricks, you can do so. In that case, please create a new section for the needed code cells you created accompanied with either code comments or markdown.  </li>
# <li>Any other ideas about this dataset? Any ways to expand or improve the dataset and the analysis?</li>
# <li>This notebook mostly concentrates on the most productive honey producers. You can also inspect different quantiles (df2, df3, df4). Are there any differences when compared to the top DataFrame?</li>

# %% [markdown]
# <hr />

# %% [markdown]
# <div style="border: 3px dashed white; padding: 10px;">
# <h3>Question 1</h3>
#
# Can you find any states that have got more successful in terms of different variables in this dataset?
#
# <h3>Answer </h3>
#
# Yes,<strong style='color:red'> North Dakota seems to be having a value_production boom</strong>  while other states seem to be having downward or slightly upward correlation trends in the variable.
#
# ![image.png](attachment:image.png)
#
# The state <strong style='color:red'>California seems to be a good place to place a honey farm, at least from a stockprice perspective</strong> If investors are looking to increase the stock price alone and they had the ability to get a lot of colonies, the best effect would be to invest in colonies in California
#
# ![image-2.png](attachment:image-2.png)
#
# If maximized honey production would be available, <strong style='color:red'>Florida has a great trending effect on the stock price based on production</strong>
#
# ![image-3.png](attachment:image-3.png)
#
#
#
# </div>

# %% [markdown]
# <div style="border: 3px dashed white; padding: 10px;">
# <h3>Question 2</h3>
#
# Something has happened to honey production overall during the years. Which variables show this best? Can you find anything with Google why this phenomenon might have a happened?
#
# <h3> Answer </h3>
#
# <strong style='color:red'>Honey yield / colony has gone down in the US!</strong>
#
# ![image.png](attachment:image.png)
#
# The honey yield / colony variable seems to be the best variable, since it is most likely to be the causational factor of the production going down as well.
#
# Some googling:
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# </div>

# %% [markdown]
# <div style="border: 3px dashed white; padding: 10px;">
# <h3>Question 3</h3>
#
# Which seaborn plots are useful in this notebook, and which are not? Why? (you can remove the unnecessary plots from this notebook if you wish too). Note: there are many not-so-useful plots in this notebook.
#
# <strong style='color:red'> All of the ones without a hue attribute are not-so-useful. </strong>
#
# This one is a little hard to read, maybe getting rid of the confidence intervals would help.
#
# ![image.png](attachment:image.png)
#
# A lot of the box plots could be more useful by using a graph instead.
#
# ![image-2.png](attachment:image-2.png)
#
# It doesn't make sense to place these two variables together. Stock/stockprice is certainly a factor that can be considered, but long-term, the yield / colony is an <strong style='color:red'> uncontrollable factor which we can do little to change</strong>. There are another few plots just like this. It shows interesting information, but how can we make business decisions from these insights?
#
# ![image-3.png](attachment:image-3.png)
#
# ??? This one is very confusing.
#
# ![image-4.png](attachment:image-4.png)
#
# So that means the ratio is this.
#
# colonies number * (yield / colony) with the y-axis as colonies number. This might not be as intuitive as it could be.
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# All the other ones seem to be okay. My favorite one is this plot.
#
# ![image-7.png](attachment:image-7.png)
#
# It shows a clear problem where we can establish an a business-insight (should I make a honeyfarm y/n)
#
# </div>

# %% [markdown]
# <div style="border: 3px dashed white; padding: 10px;">
# <h3>Question 4</h3>
#
# Which are more useful in this case, correlations or plots? Or are they both useful?
#
# <h3>Answer </h3>
# The <strong style='color:red'>plots are more useful.</strong> The data is often needs to be categorized by states to get a clear visual of what's going on. Without the hue effect, I think there's a bit less insight to be made. Visualizing the data by states is very useful.
# </div>

# %% [markdown]
# <div style="border: 3px dashed white; padding: 10px;">
# <h3>Question 5</h3>
#
# How does the hue change the perspective of the data in the regression plots?
#
# <h3>Answer </h3>
#
# Instead of a general downwards trend in honey yield per colony, it shows which state is suffering less and more. That is useful informoration, since we could go into a deeper analysis to compare worse-yielding state and better-yielding states to find explanations. It worked the same way with the first exercise, where not much can be extrapolated without hue aside from the basics, I.E. bakery sales have gone up and that seasonality exists.
#
# </div>

# %% [markdown]
# ---

# %% [markdown]
# ## Advanced Questions

# %% [markdown]
# <div style="border: 3px dashed white; padding: 10px;">
# <h3>Question 1</h3>
#
# If you find new insight or features in this dataset by using some other plots and/or pandas tricks, you can do so. In that case, please create a new section for the needed code cells you created accompanied with either code comments or markdown.
#
#
# <h3>See code below.</h3>
# </div>

# %% [markdown]
# <div style="border: 3px dashed white; padding: 10px;">
# <h3>Question 2</h3>
#
# Any other ideas about this dataset? Any ways to expand or improve the dataset and the analysis?
#
# <h3> Answer </h3>
#
# From my code-section it appeared that states that are expensive to live in received much bigger dips in production over the years.
#
# Therefore, it would be interesting to <strong style='color: red'> concatinate real-estate data to this dataset</strong>
#
# </div>

# %% [markdown]
# <div style="border: 3px dashed white; padding: 10px;">
# <h3>Question 3</h3>
#
# This notebook mostly concentrates on the most productive honey producers. You can also inspect different quantiles (df2, df3, df4). Are there any differences when compared to the top DataFrame?
#
# <h3>Answer</h3>
#
#
#
# </div>

# %% [markdown]
# <hr />

# %% [markdown]
# <h4><b>Imports and load the original dataset</b></h4>

# %%
# import the common data analytics modules
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <h4><b>Load the dataset and clean up data</b></h4>

# %%
# load the dataset and remove first column (duplicate index)
df = pd.read_csv("US_honey_dataset.csv")
del df[df.columns[0]]

# let's see how many different states we have here (44 in total)
states = df['state'].value_counts()
print(states)

print("\nAmount of different states:")
print(len(states))

# create a helper DataFrame and group by state and production
values = df.groupby('state').sum().sort_values(by=['production'], ascending=False)

# get lists of states by production, one for each 25% quantile
df_highest = list(values.query('production >= production.quantile(q=0.75)').index)
df_average_plus = list(values.query('production >= production.quantile(q=0.50) and production < production.quantile(q=0.75)').index)
df_average_minus = list(values.query('production >= production.quantile(q=0.25) and production < production.quantile(q=0.50)').index)
df_lowest = list(values.query('production < production.quantile(q=0.25)').index)

# filter the corresponding states into their DataFrames
df1 = df[df['state'].isin(df_highest)]
df2 = df[df['state'].isin(df_average_plus)]
df3 = df[df['state'].isin(df_average_minus)]
df4 = df[df['state'].isin(df_lowest)]

# let's save the correlation matrices too
correlations = df.corr(numeric_only=True)
correlations1 = df1.corr(numeric_only=True)
correlations2 = df2.corr(numeric_only=True)
correlations3 = df3.corr(numeric_only=True)
correlations4 = df4.corr(numeric_only=True)

# the data is otherwise fairly clean
# Out:
# state
# Alabama          27
# Arizona          27
# Arkansas         27
# California       27
# Colorado         27
# Florida          27
# Georgia          27
# Hawaii           27
# Idaho            27
# Illinois         27
# Indiana          27
# Iowa             27
# Kansas           27
# Louisiana        27
# Maine            27
# Michigan         27
# Mississippi      27
# Minnesota        27
# Montana          27
# Missouri         27
# NorthCarolina    27
# NewYork          27
# Nebraska         27
# NewJersey        27
# Pennsylvania     27
# Oregon           27
# Ohio             27
# NorthDakota      27
# Washington       27
# WestVirginia     27
# Vermont          27
# Virginia         27
# Tennessee        27
# SouthDakota      27
# Utah             27
# Texas            27
# Wisconsin        27
# Wyoming          27
# Kentucky         26
# NewMexico        18
# Nevada           15
# SouthCarolina    12
# Maryland          9
# Oklahoma          9
# ...

# %% [markdown]
# <h4><b>seaborn plotting - pair plots</b></h4>

# %%
# pair plot, hue on state
sns.pairplot(df1, hue="state")

# %% [markdown]
# <h4><b>seaborn plotting - regression plots</b></h4>

# %%
# regression plot for value of production and year, hue on state
sns.lmplot(x='year', y='value_of_production', data=df1, hue='state', palette="tab10")

# %%
# regression plot for value of average price and year, hue on state
sns.lmplot(x='year', y='average_price', data=df1, hue='state')

# %%
# regression plot for yield per colony and year, hue on state
sns.lmplot(x='year', y='yield_per_colony', data=df1, hue='state')

# %%
# regression plot for production and year, hue on state
sns.lmplot(x='year', y='production', data=df1, hue='state')

# %%
# regression plot for yield per colony and stocks, hue on state
sns.lmplot(x='stocks', y='yield_per_colony', data=df1, hue='state', palette='tab10')

# %%
# regression plot for colonies number and stocks, hue on state
sns.lmplot(x='stocks', y='colonies_number', data=df1, hue='state')

# %%
# regression plot for production and stocks, hue on state
sns.lmplot(x='stocks', y='production', data=df1, hue='state')

# %%
# regression plot for yield per colony and colonies number, hue on state
sns.lmplot(x='colonies_number', y='yield_per_colony', data=df1, hue='state')

# %%
# regression plot for stocks and year, hue on state
sns.lmplot(x='year', y='stocks', data=df1, hue='state')

# %%
# regression plot for value of production and yield per colony, hue on state
sns.lmplot(x='yield_per_colony', y='value_of_production', data=df1, hue='state')

# %%
# regression plot for value of production and production, hue on state
sns.lmplot(x='production', y='value_of_production', data=df1, hue='state')

# %%
# regression plot for colonies number and production, hue on state
sns.lmplot(x='production', y='colonies_number', data=df1, hue='state')

# %% [markdown]
# <h4><b>seaborn plotting - box plots</b></h4>

# %%
# just out of curiosity... can be see something if we use decades instead of years 
# for boxplot (too many different years for a boxplot otherwise)
df_four_big = df[df['state'].isin(['California', 'Florida', 'NorthDakota', 'SouthDakota'])].copy()

def create_year_spans(row):
    year = int(row['year'])
    
    if year < 2000:
        return 1990
    elif 2000 <= year <= 2010:
        return 2000
    else:
        return 2010

# create new column for decade and drop original year
df_four_big['decade'] = df_four_big.apply(create_year_spans, axis=1)
df_four_big = df_four_big.drop('year', axis=1)

# %%
# box plot on decade andp production, hue on state
sns.boxplot(x='decade', y='production', data=df_four_big, hue='state')
# Out:
# <Axes: xlabel='decade', ylabel='production'>

# %%
# box plot on decade andp stocks, hue on state
sns.boxplot(x='decade', y='stocks', data=df_four_big, hue='state')
# Out:
# <Axes: xlabel='decade', ylabel='stocks'>

# %%
# box plot on decade and value of production, hue on state
sns.boxplot(x='decade', y='value_of_production', data=df_four_big, hue='state')
# Out:
# <Axes: xlabel='decade', ylabel='value_of_production'>

# %%
# box plot on decade and yield per colony, hue on state
sns.boxplot(x='decade', y='yield_per_colony', data=df_four_big, hue='state')
# Out:
# <Axes: xlabel='decade', ylabel='yield_per_colony'>

# %%
# box plot on decade and average price, hue on state
sns.boxplot(x='decade', y='average_price', data=df_four_big, hue='state')
# Out:
# <Axes: xlabel='decade', ylabel='average_price'>

# %%
# box plot on decade and colonies number, hue on state
sns.boxplot(x='decade', y='colonies_number', data=df_four_big, hue='state')
# Out:
# <Axes: xlabel='decade', ylabel='colonies_number'>

# %% [markdown]
# <h4><b>seaborn plotting - heatmaps</b></h4>

# %%
# heatmap for correlations for all data
sns.heatmap(correlations, annot=True)
# Out:
# <Axes: >

# %%
# heatmap for correlations for top 25% producers
sns.heatmap(correlations1, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ---

# %% [markdown]
# # Continuing EDA (Extra Question 3)

# %% [markdown]
# It would be interesting to see who the big producers of honey are currently and try to find out how things changed in production over the years.
#
# Let's try to make a visual that shows the percentage of production of the top 10 states for all years first.

# %%
df
# Out:
#              state  colonies_number  yield_per_colony  production   stocks  \
# 0          Alabama            16000                58      928000    28000
# 1          Arizona            52000                79     4108000   986000
# 2         Arkansas            50000                60     3000000   900000
# 3       California           420000                93    39060000  4687000
# 4         Colorado            45000                60     2700000  1404000
# ...            ...              ...               ...         ...      ...
# 1110      Virginia             6000                40       79000    79000
# 1111    Washington            96000                32     1206000  1206000
# 1112  WestVirginia             6000                43      136000   136000
# 1113     Wisconsin            42000                47      750000   750000
# 1114       Wyoming            38000                58      242000   242000
#
#       average_price  value_of_production  year
# ...

# %%
# Using a groupby function that sums the production for each state for all five years.
groupby = df.groupby(['state'])[['production']].sum()
groupby = groupby.sort_values('production', ascending=False).head(15)

groupby
# Out:
#              production
# state
# NorthDakota   513742000
# California    423876000
# SouthDakota   355726000
# Florida       280934000
# Montana       197173000
# Minnesota     176581000
# Texas         129441000
# Michigan      101063000
# Wisconsin      99909000
# Idaho          87188000
# NewYork        78444000
# Nebraska       63655000
# Louisiana      60568000
# Georgia        57426000
# Washington     53238000

# %% [markdown]
# <div style="border: 3px dashed white; padding: 10px;">
# <h3>Observations</h3>
#
# We can see that North Dakota and California at the top producers. It's interesting, but not really insightful, since the column 'production' is just a number. We need to make it relative.
#
# Let's store a variable that has the sum of all production for all years, and divide it by all production to get a better look
#
# </div>

# %%
# Storing a variable with the production of all states and all years.
sum_all_states = groupby['production'].sum()

# Then we make a new column and have it be equals to the production / sum_all_states.
groupby['production_ratio'] = groupby['production'] / sum_all_states

# %%
# Looks like it worked. Very good
groupby['production_ratio']
# Out:
# state
# NorthDakota    0.191769
# California     0.158224
# SouthDakota    0.132785
# Florida        0.104867
# Montana        0.073600
# Minnesota      0.065914
# Texas          0.048318
# Michigan       0.037725
# Wisconsin      0.037294
# Idaho          0.032545
# NewYork        0.029281
# Nebraska       0.023761
# Louisiana      0.022609
# Georgia        0.021436
# Washington     0.019873
# Name: production_ratio, dtype: float64

# %%
# Checking more work
groupby
# Out:
#              production  production_ratio
# state
# NorthDakota   513742000          0.191769
# California    423876000          0.158224
# SouthDakota   355726000          0.132785
# Florida       280934000          0.104867
# Montana       197173000          0.073600
# Minnesota     176581000          0.065914
# Texas         129441000          0.048318
# Michigan      101063000          0.037725
# Wisconsin      99909000          0.037294
# Idaho          87188000          0.032545
# NewYork        78444000          0.029281
# Nebraska       63655000          0.023761
# Louisiana      60568000          0.022609
# Georgia        57426000          0.021436
# Washington     53238000          0.019873

# %%
# Let's practice a bit of matplotlib. Let's make a pie chart that shows the percentages.
import matplotlib.pyplot as plt

# Calling the values and labels for the pie chart.
# Since groupby dataframes function a little bit differently, we call the first column
# as the 'index'
labels = groupby.index
sizes = groupby['production']

# Configuring the plot
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', textprops={'fontsize': 8})

# Getting rid of the warnings.
plt.show()

# %% [markdown]
# <div style="border: 3px dashed white; padding: 10px;">
# <h3>Observations</h3>
#
# We notice that California and The Dakotas have really been at the fore-front of honey production over the years. I wonder how this new event(less honey yield/colony) will change this situation?
#
# Let's take a look at the original dataset again to find out.
#
# </div>

# %%
df
# Out:
#              state  colonies_number  yield_per_colony  production   stocks  \
# 0          Alabama            16000                58      928000    28000
# 1          Arizona            52000                79     4108000   986000
# 2         Arkansas            50000                60     3000000   900000
# 3       California           420000                93    39060000  4687000
# 4         Colorado            45000                60     2700000  1404000
# ...            ...              ...               ...         ...      ...
# 1110      Virginia             6000                40       79000    79000
# 1111    Washington            96000                32     1206000  1206000
# 1112  WestVirginia             6000                43      136000   136000
# 1113     Wisconsin            42000                47      750000   750000
# 1114       Wyoming            38000                58      242000   242000
#
#       average_price  value_of_production  year
# ...

# %%
# If we were to make a simple lineplot with all the states, the data would be unreadable.
# df1 (top quantile) is an option too, but I would like even less lines than that. Maximum clarity!

# Filter by aggregate the top 5 states in production
top_states_production = df.groupby('state')['production'].sum().nlargest(5).index

# Matching the dataframes to those 5 top states
top_df = df[df['state'].isin(top_states_production)]

# Showing the plot
sns.lineplot(top_df,x='year', y='production', hue='state')
# Out:
# <Axes: xlabel='year', ylabel='production'>

# %% [markdown]
# <div style="border: 3px dashed white; padding: 10px;">
# <h3>Observations</h3>
#
# This is incredibly interesting. At first, California was the lead producer of honey production but as the honey-yield / colony went down, the production went down
#
# further than other states.
#
# <h3> My hypothesis </h3>
#
# Notice how both the states Florida and California both received significant dips in production. Based on my experience living in the US, these are both states that have on average higher real
# estate prices (they also have high population density). Below is a source that reinforces this theory somewhat.
#
#  <strong>[Source](https://worldpopulationreview.com/state-rankings/most-expensive-states-to-live-in)</strong>
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
#
# It might be that because the honey-yield is so low, that it's not worth producing honey anymore in those states because the real-estate prices are high.
#
# ![image-3.png](attachment:image-3.png)
#
# </div>

# %% [markdown]
# ---

# %% [markdown]
# # Quantiles (Extra Question 4)

# %% [markdown]
# ### Honey production

# %%
# Creates a plot with multiple subplots.
fig, axes = plt.subplots(1, 4, figsize=(25, 5))
sns.lineplot(df1,x='year', y='production', hue='state', ax=axes[0])
sns.lineplot(df2,x='year', y='production', hue='state', ax=axes[1])
sns.lineplot(df3,x='year', y='production', hue='state', ax=axes[2])
sns.lineplot(df4,x='year', y='production', hue='state', ax=axes[3])

# Prevents overlap between graphs
plt.tight_layout()

# Shows the plots
plt.show()

# %% [markdown]
# ### Average Price

# %%
# Creates a plot with multiple subplots.
fig, axes = plt.subplots(1, 4, figsize=(25, 5))
sns.lineplot(df1,x='year', y='average_price', hue='state', ax=axes[0])
sns.lineplot(df2,x='year', y='average_price', hue='state', ax=axes[1])
sns.lineplot(df3,x='year', y='average_price', hue='state', ax=axes[2])
sns.lineplot(df4,x='year', y='average_price', hue='state', ax=axes[3])

# Prevents overlap between graphs
plt.tight_layout()

# Shows the plots
plt.show()

# %% [markdown]
# ### Honey-yield

# %%
# Creates a plot with multiple subplots.
fig, axes = plt.subplots(1, 4, figsize=(25, 5))
sns.lineplot(df1,x='year', y='yield_per_colony', hue='state', ax=axes[0])
sns.lineplot(df2,x='year', y='yield_per_colony', hue='state', ax=axes[1])
sns.lineplot(df3,x='year', y='yield_per_colony', hue='state', ax=axes[2])
sns.lineplot(df4,x='year', y='yield_per_colony', hue='state', ax=axes[3])

# Prevents overlap between graphs
plt.tight_layout()

# Shows the plots
plt.show()

# %% [markdown]
# <div style="border: 3px dashed white; padding: 10px;">
# <h3>Observations</h3>
#
# I'm not seeing very much from basic lineplots here. From this at least, we can say that some plots look very similar.
#
# Let's look at maybe some correlation matrices.
#
# </div>

# %%
# Making the correlation data
correlation_1 = df1.corr(numeric_only=True)
correlation_2 = df2.corr(numeric_only=True)
correlation_3 = df3.corr(numeric_only=True)
correlation_4 = df4.corr(numeric_only=True)


# Setting the canvas for four subplots and initializing each matrix.
fig, axes = plt.subplots(2, 2, figsize=(15, 15))
sns.heatmap(correlation_1, annot=True, cmap='coolwarm', ax=axes[0, 0])
sns.heatmap(correlation_2, annot=True, cmap='coolwarm', ax=axes[0, 1])
sns.heatmap(correlation_3, annot=True, cmap='coolwarm', ax=axes[1, 0])
sns.heatmap(correlation_4, annot=True, cmap='coolwarm', ax=axes[1, 1])


# Prevents overlap between graphs
plt.tight_layout()

# Shows the plots
plt.show()

# %% [markdown]
# <div style="border: 3px dashed white; padding: 10px;">
# <h3>Observations</h3>
#
# This shows much more interesting info than the plots. It looks like df1 (the top quantile) has some distinctions from the other quantiles.
#
# The yield_per_colony to colonies_number correlation is ever-so-slightly-positive for df1, while the others are negative
#
# You can see differences more distinctions this way as well.
# </div>

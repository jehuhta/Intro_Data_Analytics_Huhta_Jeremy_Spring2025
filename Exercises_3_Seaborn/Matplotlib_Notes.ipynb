# %% [markdown]
# # Advanced Exercise 4

# %% [markdown]
# <ul>
# <li><b>4. Try out any of the previous examples and exercises by using any or many
# of the following additional plotting libraries:<br /><br />
# </li>
# <ul>
# <li><b>Matplotlib (this is the most common in addition to seaborn,
# especially regarding machine learning, recommended to learn)</b><br />
# <a href="https://matplotlib.org/stable/tutorials/index.html#introductory">https://matplotlib.org/stable/tutorials/index.html#introductory</a><br /><br /></li>
# <li><b>Plotly</b><br />
# <a href="https://plotly.com/python/getting-started/">https://plotly.com/python/getting-started/</a><br /><br /></li>
# <li><b>Bokeh</b><br /><a href="https://docs.bokeh.org/en/latest/docs/user_guide.html">https://docs.bokeh.org/en/latest/docs/user_guide.html</a>
# <br /><br /></li>
# </ul>
# </ul>
# <img src="http://srv.plab.fi/~tuomasv/data_analytics_2023_images/exercise_set_3/charts.png" />

# %% [markdown]
# # Matplotlib Experimentation

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset('penguins')
df.head(3)

# %% [markdown]
# ## Using a basic scatterplot (perhaps the Hello World of matplotlib)

# %%
# Let's go through the matplotlib tutorials and familiarize ourselves
# with the basics.

# A basic scatterplot
plt.scatter(df['bill_depth_mm'], df['body_mass_g'])
plt.ylabel('Mass in grams')
plt.xlabel('Bill length in milimeters')

plt.show()

# %% [markdown]
# ## Making the three basic plots with matplot lib using subplots

# %%
# Generating count values for each species.
species_adelie = (df['species'] == 'Adelie').sum()
species_gentoo = (df['species'] == 'Gentoo').sum()
species_chinstrap = (df['species'] == 'Chinstrap').sum()

# Turning the species values into 'values', and labels by 'names.'
names = ['Adelie', 'Gentoo', 'Chinstrap']
values = [species_adelie, species_gentoo, species_chinstrap]

# This is the figure size. It changes the  width and height of the entire canvas.
plt.figure(figsize=(9, 3))

# Subplots are inserted into the canvas, in positions given in the parameters ex: (131) 

# 1st number: is for the row.
# 2nd number: is for the column.
# 3rd number: is for the index of the subplot. (order, basically.)
 
plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# Let's switch things around in the next one to experiment more with it.

# %%
plt.figure(figsize=(9, 3))

# A different order in subplots. The reason this is happening is because the
# last number has been changed in the parameter. 

plt.subplot(133)
plt.bar(names, values)
plt.subplot(131)
plt.scatter(names, values)
plt.subplot(132)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# Let's change it up one more time, just to drive the point home.

# %% [markdown]
# Note that it doesn't make sense to use the first two types of plots, and that a bar chart would be more appropriate

# %%
# This doesn't look great, but it is mainly to show that there
# is quite a bit of subplot customization here. It can be quite
# Finnicky.

plt.subplot(233)
plt.bar(names, values)
plt.subplot(331)
plt.scatter(names, values)
plt.subplot(142)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %% [markdown]
# ## Using markers and colors when plotting

# %% [markdown]
# ---
# ### A guide to help me:
#
# #### Line styles
# ![image.png](attachment:image.png)
#
# #### Markers
# ![image-2.png](attachment:image-2.png)
#
#
# #### Colors
# ![image-3.png](attachment:image-3.png)
#
# *Taken from w3schools/python/matplotlib_line.asp*
#
# ---

# %% [markdown]
# #### Application

# %%
# A different order in subplots. The reason this is happening is because the
# last number has been changed in the parameter.

# Different markers
# Row 1
plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.plot(names, values)
plt.subplot(132)
plt.plot(names, values, marker='o')
plt.subplot(133)
plt.plot(names, values, marker='*')
plt.suptitle('Categorical Plotting')
plt.show()

# Dashed lines and colors
# Row 2
plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.plot(names, values)
plt.subplot(132)
plt.plot(names, values, 'o:r')
plt.subplot(133)
plt.plot(names, values, '*:g')
plt.suptitle('Categorical Plotting')
plt.show()

# Changing marker size
# Row 3
plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.plot(names, values)
plt.subplot(132)
plt.plot(names, values, 'o:r', ms= 20)
plt.subplot(133)
plt.plot(names, values, '*:g', ms = 20, mec='r')
plt.suptitle('Categorical Plotting')
plt.show()

# %% [markdown]
# Just to make it clear again, the data doesn't make much sense here, we're just trying the features. (Normally, we would want a barchart or scatterplot)

# %% [markdown]
# ## Linesizes

# %%
# A series of subplots to check out line-sizes. The attribute linewidth determines the
# width of the line on the plot.
plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.plot(names, values)
plt.subplot(132)
plt.plot(names, values, 'o:r', linewidth='10')
plt.subplot(133)
plt.plot(names, values, '*:g', linewidth='13')
plt.suptitle('Categorical Plotting')
plt.show()

# %% [markdown]
# ## More advanced code

# %%
# I left this here to show everyone a work of art. Behold.

species_adelie = df[df['species'] == 'Adelie']
species_gentoo = df[df['species'] == 'Gentoo']
species_chinstrap = df[df['species'] == 'Chinstrap']


x1 = species_adelie['bill_depth_mm']
y1 = species_adelie['body_mass_g']
x2 = species_gentoo['bill_depth_mm']
y2 = species_gentoo['body_mass_g']
x3 = species_chinstrap['bill_depth_mm']
y3 = species_chinstrap['body_mass_g']

plt.plot(x1, y1, x2, y2, x3, y3)
plt.show()

# This is a great example for how not to make a scatterplot. This would have worked
# If we were making multiple line graphs.

# %%
# A bit more complicated plot. A scatterplot using hues
# just like seaborn. 

# Filter species
species_adelie = df[df['species'] == 'Adelie']
species_gentoo = df[df['species'] == 'Gentoo']
species_chinstrap = df[df['species'] == 'Chinstrap']

# Extract coordinates
x1, y1 = species_adelie['bill_depth_mm'], species_adelie['body_mass_g']
x2, y2 = species_gentoo['bill_depth_mm'], species_gentoo['body_mass_g']
x3, y3 = species_chinstrap['bill_depth_mm'], species_chinstrap['body_mass_g']

# Plot each species with style
plt.scatter(x1, y1, color='purple', label='Adelie')
plt.scatter(x2, y2, color='orange', label='Gentoo')
plt.scatter(x3, y3, color='green', label='Chinstrap')

plt.xlabel('Bill Depth (mm)')
plt.ylabel('Body Mass (g)')
plt.title('Penguin Species Comparison')
plt.legend(title='Species')
plt.show()

# In hindsight, this is a lot of code for something that is a simple 'hue'
# attribute in Seaborn.
